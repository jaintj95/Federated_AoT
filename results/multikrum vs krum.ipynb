# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import gc
import json
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.preprocessing import OneHotEncoder
from tqdm import tqdm
from sklearn.decomposition import PCA
import os
import imagesize

# %matplotlib inline

# %%
data = pd.read_csv("multi_krum vs krum_acc_results - southwest_vgg16_blackbox_without_replacement_krum_acc_results.csv")

print("{} data".format(data.shape[0]))
# Out:
# 200 data

# %%
data.head()
# Out:
#    fl_iter  main_task_acc(k)  backdoor_acc(k)  raw_task_acc(k)  \
# 0        1              10.0              0.0              0.0
# 1        2              10.0              0.0              0.0
# 2        3              10.0              0.0              0.0
# 3        4              10.0              0.0              0.0
# 4        5              10.0              0.0              0.0
#
#    adv_norm_diff(k)  wg_norm(k)  main_task_acc(mk)  backdoor_acc(mk)  \
# 0          1.216249   88.166756               9.94          0.000000
# 1          0.000000   88.157349              11.01          0.000000
# 2          0.000000   88.139595               8.88         86.734694
# 3          0.000000   88.134102              10.00          0.000000
# 4          0.000000   88.128571              10.00          0.000000
#
#    raw_task_acc(mk)  adv_norm_diff(mk)  wg_norm(mk)
# 0               0.0           1.216249    88.166756
# 1               0.0           0.000000    88.143105
# ...

# %% [markdown]
# ###  WITH RESPECT TO "backdoor_acc" PARAMETER KRUM DEFENSE VS MULTIKRUM DEFENSE

# %%
data.plot.scatter('backdoor_acc(k)','backdoor_acc(mk)')

# %% [markdown]
# ###  WITH RESPECT TO "main_task_acc" PARAMETER KRUM DEFENSE VS MULTIKRUM DEFENSE

# %%
data.plot.scatter('main_task_acc(k)','main_task_acc(mk)')

# %% [markdown]
# ###  WITH RESPECT TO "raw_task_acc" PARAMETER KRUM DEFENSE VS MULTIKRUM DEFENSE

# %%
data.plot.scatter('raw_task_acc(k)','raw_task_acc(mk)')

# %% [markdown]
# ###  WITH RESPECT TO "wg_norm" PARAMETER KRUM DEFENSE VS MULTIKRUM DEFENSE

# %%
data.plot.scatter('wg_norm(k)','wg_norm(mk)')

# %% [markdown]
# ### WITH RESPECT TO "adv_norm_diff" PARAMETER KRUM DEFENSE VS MULTIKRUM DEFENSE

# %%
data.plot.scatter('adv_norm_diff(k)','adv_norm_diff(mk)')

# %% [markdown]
# ### WITH RESPECT TO "main_task_acc" PARAMETER KRUM DEFENSE

# %%
data.plot.scatter('main_task_acc(k)','fl_iter')

# %% [markdown]
# ### WITH RESPECT TO "main_task_acc" PARAMETER  MULTIKRUM DEFENSE

# %%
data.plot.scatter('main_task_acc(mk)','fl_iter')

# %% [markdown]
# ### WITH RESPECT TO "backdoor_acc" PARAMETER KRUM DEFENSE

# %%
data.plot.scatter('backdoor_acc(k)','fl_iter')

# %% [markdown]
# ### WITH RESPECT TO "backdoor_acc" PARAMETER MULTIKRUM DEFENSE

# %%
data.plot.scatter('backdoor_acc(mk)','fl_iter')

# %% [markdown]
# ### WITH RESPECT TO "raw_task_acc" PARAMETER KRUM DEFENSE

# %%
data.plot.scatter('raw_task_acc(k)','fl_iter')

# %% [markdown]
# ### WITH RESPECT TO "raw_task_acc" PARAMETER MULTIKRUM DEFENSE

# %%
data.plot.scatter('raw_task_acc(mk)','fl_iter')
